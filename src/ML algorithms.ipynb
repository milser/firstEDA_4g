# %% [markdown]
# # EDA - Exploratory Data Analysis
#
# ### Day 01
#
# #### Paso 1. Definir el problema y carga de datos
#
# El problema que se pretende abordar con el conjunto de datos es asdasdandsassd ............................................ asdfasdassadasdasd
# asdasda
# - s
# - s
# - s

# %%
import pandas as pd

train_data = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/machine-learning-content/master/assets/titanic_train.csv")
test_data = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/machine-learning-content/master/assets/titanic_test.csv")
test_survived_data = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/machine-learning-content/master/assets/gender_submission.csv")
test_data["Survived"] = test_survived_data["Survived"]

# Unir train y test
total_data = pd.concat([train_data, test_data]).reset_index(drop = True)
total_data
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# ...           ...       ...     ...
# 1304         1305         0       3
# 1305         1306         1       1
# 1306         1307         0       3
# 1307         1308         0       3
# 1308         1309         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# #### Paso 2. Exploración y limpieza superficial
#
# ##### 1. Dimensiones del problema

# %%
total_data.shape
# Out:
# (1309, 12)

# %% [markdown]
# El dataset contiene 1309 instancias y 12 variables, de las cuales 1 es la clase (`Survive`) y las otras 11, predictoras.
#
# ##### 2. Valores nulos / no nulos

# %%
total_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     1309 non-null   int64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 122.8+ KB

# %%
total_data.isnull().sum()
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %% [markdown]
# sdasdasdadsasdsad
# asd
# dasdas
# das
# das
# das
# das
# d
#
# ##### 3. Eliminar los duplicados

# %%
len(total_data)
# Out:
# 1309

# %%
total_data.drop_duplicates(total_data.columns.difference(["PassengerId"]))
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# ...           ...       ...     ...
# 1304         1305         0       3
# 1305         1306         1       1
# 1306         1307         0       3
# 1307         1308         0       3
# 1308         1309         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# ##### 4. Eliminar información vacía

# %%
total_data.drop(["PassengerId", "Name", "Ticket", "Cabin"], axis = 1, inplace = True)

# %%
total_data
# Out:
#       Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0            0       3    male  22.0      1      0    7.2500        S
# 1            1       1  female  38.0      1      0   71.2833        C
# 2            1       3  female  26.0      0      0    7.9250        S
# 3            1       1  female  35.0      1      0   53.1000        S
# 4            0       3    male  35.0      0      0    8.0500        S
# ...        ...     ...     ...   ...    ...    ...       ...      ...
# 1304         0       3    male   NaN      0      0    8.0500        S
# 1305         1       1  female  39.0      0      0  108.9000        C
# 1306         0       3    male  38.5      0      0    7.2500        S
# 1307         0       3    male   NaN      0      0    8.0500        S
# 1308         0       3    male   NaN      1      1   22.3583        C
#
# [1309 rows x 8 columns]

# %% [markdown]
# #### Paso 3. Análisis univariante
#
# - Variable categórica -> Histogramas
# - Variable continua / numérica -> Histogramas discretizados, líneas (ordenando datos de menor a mayor) y boxplots.
#
# 'Survived': Categórica
# 'Pclass': Categórica
# 'Sex': Categórica
# 'Age': Numérica
# 'SibSp': Categórica
# 'Parch': Categórica
# 'Fare': Numérica
# 'Embarked': Categórica

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axis = plt.subplots(2, 3, figsize = (10, 7))

sns.histplot(total_data, x = "Survived", ax = axis[0, 0])
sns.histplot(total_data, x = "Pclass", ax = axis[0, 1])
sns.histplot(total_data, x = "Sex", ax = axis[0, 2])
sns.histplot(total_data, x = "SibSp", ax = axis[1, 0])
sns.histplot(total_data, x = "Parch", ax = axis[1, 1])
sns.histplot(total_data, x = "Embarked", ax = axis[1, 2])

plt.show()

# %% [markdown]
# asdasdsadsadsasdadsa
# adsa
# dasdsasdadsadasdsadsasdasda
# sdadsasaddsa
# sad
# dsadsaasddsasdasda

# %%
fig, axis = plt.subplots(2, 2, figsize = (10, 7))

sns.histplot(total_data, x = "Age", ax = axis[0, 0])
sns.boxplot(total_data, x = "Age", ax = axis[1, 0])

sns.histplot(total_data, x = "Fare", ax = axis[0, 1])
sns.boxplot(total_data, x = "Fare", ax = axis[1, 1])

plt.show()

# %% [markdown]
# dsasdaasdasdasasddsadsadsadsafgdfdsfggdsfgfdfdggfdgfdsgfdsgfdsgfdsgfd
# fgdgfdsgsfdfdgs

# %% [markdown]
# #### Paso 4. Análisis multivariante
#
# ### Survive - (Sex, Pclass)

# %%
fig, axis = plt.subplots(2, 2, figsize = (10, 5))

sns.countplot(total_data, x = "Sex", hue = "Survived", ax = axis[0, 0])
sns.countplot(total_data, x = "Pclass", hue = "Survived", ax = axis[0, 1])
sns.countplot(total_data, x = "Sex", hue = "Pclass", ax = axis[1, 0])

plt.show()

# %% [markdown]
# ### Fare - Age

# %%
fig, axis = plt.subplots(2, 1, figsize = (5, 5))

sns.regplot(total_data, x = "Fare", y = "Age", ax = axis[0])
sns.heatmap(total_data[["Age", "Fare"]].corr(), ax = axis[1], annot = True)

plt.show()

# %%
total_data["Sex_n"] = pd.factorize(total_data["Sex"])[0]
total_data
# Out:
#       Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked  Sex_n
# 0            0       3    male  22.0      1      0    7.2500        S      0
# 1            1       1  female  38.0      1      0   71.2833        C      1
# 2            1       3  female  26.0      0      0    7.9250        S      1
# 3            1       1  female  35.0      1      0   53.1000        S      1
# 4            0       3    male  35.0      0      0    8.0500        S      0
# ...        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 1304         0       3    male   NaN      0      0    8.0500        S      0
# 1305         1       1  female  39.0      0      0  108.9000        C      1
# 1306         0       3    male  38.5      0      0    7.2500        S      0
# 1307         0       3    male   NaN      0      0    8.0500        S      0
# 1308         0       3    male   NaN      1      1   22.3583        C      0
#
# [1309 rows x 9 columns]

# %%
# pip install openpyxl <- Ejecutar antes del to_excel

total_data.drop_duplicates(["Sex", "Sex_n"])[["Sex", "Sex_n"]].to_excel("/workspaces/ml_template/Sex_to_Sexn.xlsx", index = False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 total_data.drop_duplicates(["Sex", "Sex_n"])[["Sex", "Sex_n"]].to_excel("/workspaces/ml_template/Sex_to_Sexn.xlsx", index = False)
#
# File ~/.local/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
total_data["Sex_n"] = pd.factorize(total_data["Sex"])[0]
total_data["Embarked_n"] = pd.factorize(total_data["Embarked"])[0]

fig, axis = plt.subplots(figsize = (15, 15))

sns.heatmap(total_data[total_data.columns.difference(["Sex", "Embarked"])].corr(), annot = True, fmt = ".2f")

plt.show()

# %% [markdown]
# sadsadsdasda
# asdadssadsda
# sda

# %% [markdown]
# ### Day 02
#
# #### Paso 5. Feature engineering
#
# ##### Análisis de outliers

# %%
total_data.describe()
# Out:
#           Survived       Pclass          Age        SibSp        Parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      0.377387     2.294882    29.881138     0.498854     0.385027
# std       0.484918     0.837836    14.413493     1.041658     0.865560
# min       0.000000     1.000000     0.170000     0.000000     0.000000
# 25%       0.000000     2.000000    21.000000     0.000000     0.000000
# 50%       0.000000     3.000000    28.000000     0.000000     0.000000
# 75%       1.000000     3.000000    39.000000     1.000000     0.000000
# max       1.000000     3.000000    80.000000     8.000000     9.000000
#
#               Fare
# count  1308.000000
# mean     33.295479
# std      51.758668
# min       0.000000
# 25%       7.895800
# 50%      14.454200
# 75%      31.275000
# max     512.329200

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axis = plt.subplots(2, 3, figsize = (10, 7))

sns.boxplot(total_data, x = "Pclass", ax = axis[0, 0])
sns.boxplot(total_data, x = "Age", ax = axis[0, 1])
sns.boxplot(total_data, x = "SibSp", ax = axis[0, 2])
sns.boxplot(total_data, x = "Parch", ax = axis[1, 0])
sns.boxplot(total_data, x = "Fare", ax = axis[1, 1])

plt.show()

# %% [markdown]
# ##### Reemplazar

# %%
descr = total_data["Fare"].describe()
descr
# Out:
# count    1308.000000
# mean       33.295479
# std        51.758668
# min         0.000000
# 25%         7.895800
# 50%        14.454200
# 75%        31.275000
# max       512.329200
# Name: Fare, dtype: float64

# %%
fare_iqr = descr["75%"] - descr["25%"]
upper_l = descr["75%"] + 1.5*fare_iqr
lower_l = descr["25%"] - 1.5*fare_iqr
lower_l = 0
print(lower_l, upper_l)
outliers = total_data[total_data.Fare >= upper_l]
outliers
# Out:
# 0 66.34379999999999
#       Survived  Pclass   Age  SibSp  Parch      Fare  Sex_n  Embarked_n
# 1            1       1  38.0      1      0   71.2833      1           1
# 27           0       1  19.0      3      2  263.0000      0           0
# 31           1       1   NaN      1      0  146.5208      1           1
# 34           0       1  28.0      1      0   82.1708      0           1
# 52           1       1  49.0      1      0   76.7292      1           1
# ...        ...     ...   ...    ...    ...       ...    ...         ...
# 1288         1       1  48.0      1      1   79.2000      1           1
# 1291         1       1  30.0      0      0  164.8667      1           0
# 1298         0       1  50.0      1      1  211.5000      0           1
# 1302         1       1  37.0      1      0   90.0000      1           2
# 1305         1       1  39.0      0      0  108.9000      1           1
#
# [171 rows x 8 columns]

# %% [markdown]
# ##### Mantener

# %%
total_data.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked', 'Sex_n', 'Embarked_n'],
#       dtype='object')

# %%
total_data = total_data[['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex_n', 'Embarked_n']]
total_data.isnull().sum()
# Out:
# Survived        0
# Pclass          0
# Age           263
# SibSp           0
# Parch           0
# Fare            1
# Sex_n           0
# Embarked_n      0
# dtype: int64

# %%
total_data["familyMembers"] = total_data.Sibsp + total_data.Parch

# %%
total_data
total_data_no_outliers

# %%
total_data.columns
# Out:
# Index(['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex_n',
#        'Embarked_n'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

predictoras = ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex_n',
       'Embarked_n']
target = 'Survived'

X = total_data[predictoras]
y = total_data[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

X_train
# Out:
#       Pclass   Age  SibSp  Parch      Fare  Sex_n  Embarked_n
# 1214       1  33.0      0      0   26.5500      0           0
# 677        3  18.0      0      0    9.8417      1           0
# 534        3  30.0      0      0    8.6625      1           0
# 1174       3   9.0      1      1   15.2458      1           1
# 864        2  24.0      0      0   13.0000      0           0
# ...      ...   ...    ...    ...       ...    ...         ...
# 1095       2  25.0      0      0   10.5000      0           0
# 1130       1  48.0      1      0  106.4250      1           1
# 1294       1  17.0      0      0   47.1000      0           0
# 860        3  41.0      2      0   14.1083      0           0
# 1126       3  20.0      0      0    7.8542      0           0
#
# [916 rows x 7 columns]

# %%
X_train, X_test, y_train, y_test
X_train_no_outliers, X_test_no_outliers, y_train, y_test

# GUARDAR LOS DOS DATASETS
# Out:
#       Pclass   Age  SibSp  Parch      Fare  Sex_n  Embarked_n
# 1148       3  28.0      0      0    8.0500      0           0
# 1049       1  42.0      0      0   26.5500      0           0
# 982        3   NaN      0      0    7.7750      0           0
# 808        2  39.0      0      0   13.0000      0           0
# 1195       3   NaN      0      0    7.7500      1           2
# ...      ...   ...    ...    ...       ...    ...         ...
# 325        1  36.0      0      0  135.6333      1           1
# 919        1  41.0      0      0   30.5000      0           0
# 532        3  17.0      1      1    7.2292      0           1
# 1159       3   NaN      0      0    8.0500      1           0
# 513        1  54.0      1      0   59.4000      1           1
#
# [393 rows x 7 columns]

# %%
from sklearn.preprocessing import StandardScaler
from pickle import dump

scaler = StandardScaler()
scaler.fit(X_train)

X_train_norm = scaler.transform(X_train)
X_train_norm = pd.DataFrame(X_train_norm, index = X_train.index, columns = predictoras)

X_test_norm = scaler.transform(X_test)
X_test_norm = pd.DataFrame(X_test_norm, index = X_test.index, columns = predictoras)

dump(scaler, open("/workspaces/ml_template/normalizer.sav", "wb"))

X_train_norm.head()
# Out:
#         Pclass       Age     SibSp     Parch      Fare     Sex_n  Embarked_n
# 1214 -1.514484  0.231100 -0.475499 -0.423599 -0.136769 -0.738030   -0.579540
# 677   0.850848 -0.838000 -0.475499 -0.423599 -0.476109  1.354959   -0.579540
# 534   0.850848  0.017280 -0.475499 -0.423599 -0.500058  1.354959   -0.579540
# 1174  0.850848 -1.479459  0.437619  0.759378 -0.366354  1.354959    0.986414
# 864  -0.331818 -0.410360 -0.475499 -0.423599 -0.411965 -0.738030   -0.579540

# %%
df.to_csv()
nombre_df.to_excel()

# %%
# X_train_norm, X_test_norm, y_train, y_test
# X_train_no_outliers_norm, X_test_no_outliers_norm, y_train, y_test

# GUARDAR LOS DOS DATASETS
# GUARDAR EL MODELO DE NORMALIZACIÓN (objeto scaler)

from pickle import load

scaler = load(open("/workspaces/ml_template/normalizer.sav", "rb"))

# %%
# .......... Lo mismo con el Min-Max Scaler

X_train_scal, X_test_scal, y_train, y_test
X_train_no_outliers_scal, X_test_no_outliers_scal, y_train, y_test

# GUARDAR LOS DOS DATASETS
# GUARDAR EL MODELO DE ESCALADO MIN-MAX (objeto scaler)

# %% [markdown]
# ### Day 03
#
# ##### Feature Selection

# %%
from sklearn.feature_selection import f_classif, SelectKBest

selector_model = SelectKBest(f_classif, k = 5)
selector_model.fit(X_train, y_train)
best_variables = selector_model.get_support()
print("Mejores variables: ", best_variables)
X_train_sel = pd.DataFrame(selector_model.transform(X_train))

# %%
import pandas as pd

train_data = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/machine-learning-content/master/assets/clean_titanic_train.csv")
test_data = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/machine-learning-content/master/assets/clean_titanic_test.csv")

train_data.head()
# Out:
#    Pclass    Fare  Sex_n  Embarked_n  FamMembers  Survived
# 0     2.0  10.500    1.0         0.0         0.0         0
# 1     2.0  26.000    0.0         0.0         1.0         1
# 2     3.0   7.750    1.0         2.0         0.0         1
# 3     3.0  16.700    1.0         0.0         2.0         1
# 4     3.0  34.375    1.0         0.0         4.0         0

# %%
X_train = train_data.drop(["Survived"], axis = 1)
y_train = train_data["Survived"]
X_test = test_data.drop(["Survived"], axis = 1)
y_test = test_data["Survived"]

# %%
X_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 X_train
#
# NameError: name 'X_train' is not defined

# %%
y_train
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 1042    0
# 1043    1
# 1044    0
# 1045    0
# 1046    0
# Name: Survived, Length: 1047, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_train_pred = model.predict(X_train)
print(y_train_pred)
# Out:
# [1 0 1 ... 0 0 0]

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_train, y_train_pred)
# Out:
# 0.8586437440305635

# %%
hyperp_dict = {
    "penalty": [None, 'l2', 'l1', 'elasticnet'],
    "dual": [True, False],
    "fit_intercept": [True, False],
    "max_iter": [5, 15, 50, 100]
}

from sklearn.model_selection import GridSearchCV

grid = GridSearchCV(model, hyperp_dict, scoring = "accuracy", cv = 10)
grid
# Out:
# GridSearchCV(cv=10, estimator=LogisticRegression(),
#              param_grid={'dual': [True, False], 'fit_intercept': [True, False],
#                          'max_iter': [5, 15, 50, 100],
#                          'penalty': [None, 'l2', 'l1', 'elasticnet']},
#              scoring='accuracy')

# %%
grid.fit(X_train, y_train)
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/vscode/.local/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
grid.best_estimator_
# Out:
# LogisticRegression(max_iter=50)

# %%
grid.best_params_
# Out:
# {'dual': False, 'fit_intercept': True, 'max_iter': 50, 'penalty': 'l2'}

# %%
accuracy_score(y_train, LogisticRegression(max_iter = 50).fit(X_train, y_train).predict(X_train))
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8586437440305635

# %%
y_train_pred = grid.best_estimator_.predict(X_train)
accuracy_score(y_train, y_train_pred)
# Out:
# 0.8586437440305635

# %%
from pickle import dump

dump(grid.best_estimator_, open("/workspaces/ml_template/log_regression-max_iter-50.sav", "wb"))

# %%
grid.best_estimator_
# Out:
# LogisticRegression(max_iter=50)
